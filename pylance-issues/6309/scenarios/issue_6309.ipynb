# %% [markdown]
# SCENARIO: hovering `np.vectorize` in a notebook should show the class documentation, not only the signature
# markdown
# 84108266
# SCENARIO: hovering `np.vectorize` in a notebook should show the class documentation, not only the signature
#
# TARGET: `np.vectorize` in the code cell below
#
# TRIGGER: hover over `np.vectorize` in the notebook cell
#
# EXPECT: the hover includes the class docs, not just the callable signature stub
#
# VERIFY: if hover omits the class documentation while `help(np.vectorize)` still shows it, the bug still reproduces
#
# RECOVER: no recovery needed
# code
#
# 844eab27
# import numpy as np
#
# np.vectorize()
# help(np.vectorize)
# python
# 4
# 5

# %%
import numpy as np

np.vectorize()
help(np.vectorize)
