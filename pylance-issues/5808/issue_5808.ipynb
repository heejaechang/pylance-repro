# %% [markdown]
# SCENARIO: notebook magic lines should not produce parse errors in IPython mode
#
# TARGET: the `%pip install ...` line in the code cell below
#
# TRIGGER: open the notebook and let Pylance analyze the cell
#
# EXPECT: the magic line is accepted without `Expected expression` or source-parsing import errors
#
# VERIFY: if the notebook still shows parse errors on the magic statement, the bug still reproduces
#
# RECOVER: no recovery needed

# %%
if True:
    # %pip install -q "matplotlib>=3.4"
