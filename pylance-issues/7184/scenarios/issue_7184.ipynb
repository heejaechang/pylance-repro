# %% [markdown]
# SCENARIO: changing the kernel of an already-open notebook cell should refresh semantic tokens for newly-resolvable imports
# TARGET: the imports and the `numpy.random.random` call in the code cell below
# TRIGGER: open this notebook with no kernel selected, then select a kernel whose interpreter has `numpy` and `matplotlib` installed (without retyping or reopening the cell)
# EXPECT: after kernel selection, the cell visibly repaints so that `numpy`, `matplotlib`, and the `random` member access are semantically colored, matching how the same content renders when the notebook is opened fresh with that kernel already selected
# VERIFY: if the cell keeps the stale pre-kernel coloring (gray/muted identifiers, no member-access coloring) until you edit the cell or reopen the notebook, the bug still reproduces
# RECOVER: close the notebook without saving

# %%
import numpy
import matplotlib

numpy.random.random(10)
