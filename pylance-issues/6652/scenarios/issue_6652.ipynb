# %% [markdown]
# SCENARIO: opening a Windows-backed notebook through a WSL Remote window loses parameter hints
# TARGET: `gc.collect()` in the second code cell below
# TRIGGER: open this notebook from Windows through a WSL Remote session (for example the `/mnt/c/...` path), place the caret inside `gc.collect()`, and trigger parameter hints with `Ctrl+Shift+Space`
# EXPECT: parameter hints should appear for `gc.collect()` just as they do when the notebook is opened directly from Windows or from a WSL-native path
# VERIFY: if member completions on `gc.` work but `Ctrl+Shift+Space` on `gc.collect()` still shows no visible signature-help popup, the bug still reproduces
# RECOVER: after the notebook opens in WSL Remote, enable the suggested Python + Jupyter extensions if prompted, reload the remote window, and select a real remote interpreter/kernel before judging the result

# %%
import gc

# %%
gc.collect()
