# %% [markdown]
# # JavaScript cell-magic navigation
#
# Do not execute the cell. Put the caret on `greet` in `const greeting = greet("Ada");` and run **Go to Definition**.
#
# # CHECK: definition returns to greet in this cell
# # CHECK: hover describes the JavaScript string method

# %%
# %%js
# function greet(name) {
#     return "Hello " + name;
# }
# const greeting = greet("Ada");
# const word = "hello";
# word.toUpperCase();
